# %%
#Used in Tensorflow Model
import numpy as np
import tensorflow as tf
# !pip install tflearn
import random

#Usde to for Contextualisation and Other NLP Tasks.
import nltk
from nltk.stem.lancaster import LancasterStemmer
stemmer = LancasterStemmer()

#Other
import json
import pickle
import warnings
warnings.filterwarnings("ignore")

# %%
print("Processing the Intents.....")
with open('/content/sample_data/intents.json') as json_data:
  #/content/sample_data/intents.json
    intents = json.load(json_data)
# Out:
# Processing the Intents.....

# %% [markdown]
# # New Section

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words = []
classes = []
documents = []
ignore_words = ['?']
print("Looping through the Intents to Convert them to words, classes, documents and ignore_words.......")
for intent in intents['intents']:
    for pattern in intent['patterns']:
        # tokenize each word in the sentence
        w = nltk.word_tokenize(pattern)
        # add to our words list
        words.extend(w)
        # add to documents in our corpus
        documents.append((w, intent['tag']))
        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
# Out:
# Looping through the Intents to Convert them to words, classes, documents and ignore_words.......

# %%
print("Stemming, Lowering and Removing Duplicates.......")
words = [stemmer.stem(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

# remove duplicates
classes = sorted(list(set(classes)))

print (len(documents), "documents")
print (len(classes), "classes", classes)
print (len(words), "unique stemmed words", words)
# Out:
# Stemming, Lowering and Removing Duplicates.......
# 403 documents
# 39 classes ['admission', 'bye', 'canteen', 'college intake', 'committee', 'computerhod', 'course', 'creator', 'document', 'event', 'extchod', 'facilities', 'fees', 'floors', 'goodbye', 'greeting', 'hod', 'hostel', 'hours', 'infrastructure', 'ithod', 'library', 'location', 'menu', 'name', 'number', 'placement', 'principal', 'ragging', 'random', 'salutaion', 'scholarship', 'sem', 'sports', 'swear', 'syllabus', 'task', 'uniform', 'vacation']
# 241 unique stemmed words ["'s", '(', ')', 'a', 'about', 'ac', 'act', 'address', 'admid', 'admit', 'against', 'ai/ml', 'allot', 'am', 'an', 'and', 'antirag', 'any', 'anyon', 'ar', 'at', 'attend', 'automobl', 'av', 'avail', 'be', 'between', 'big', 'book', 'boy', 'branch', 'bring', 'build', 'by', 'bye', 'cafetar', 'cal', 'camp', 'can', 'canteen', 'capac', 'cas', 'ce', 'chat', 'chem', 'civil', 'cod', 'colleg', 'com', 'commit', 'comp', 'company', 'comput', 'conduc', 'contact', 'cours', 'cre', 'cya', 'dat', 'day', 'design', 'detail', 'develop', 'diff', 'dist', 'do', 'docu', 'doe', 'don', 'dress', 'dresscod', 'dur', 'each', 'eat', 'end', 'engin', 'ev', 'exam', 'exit', 'extc', 'facil', 'far', 'fee', 'first', 'flo', 'food', 'for', 'four', 'from', 'funct', 'gam', 'get', 'girl', 'giv', 'go', 'good', 'goodby', 'got', 'gtg', 'guy', 'hav', 'hel', 'held', 'hello', 'help', 'her', 'heyy', 'hi', 'hist', 'hod', 'holiday', 'hostel', 'hour', 'how', 'i', 'idiot', 'in', 'incid', 'info', 'inform', 'infrastruct', 'intak', 'is', 'it', 'job', 'juny', 'k', 'lat', 'leav', 'lect', 'libr', 'list', 'loc', 'long', 'lov', 'mad', 'many', 'marry', 'max', 'maxim', 'me', 'mech', 'menu', 'mor', 'much', 'my', 'nam', 'nee', 'next', 'nic', 'no', 'non-ac', 'numb', 'of', 'off', 'ok', 'okay', 'okk', 'oky', 'on', 'op', 'org', 'pack', 'per', 'phon', 'plac', 'pleas', 'pract', 'princip', 'process', 'provid', 'quit', 'rag', 'reach', 'recruit', 'requir', 'room', 'saturday', 'schedule', 'scholarship', 'scholarships', 'seat', 'second', 'see', 'sem', 'semest', 'serv', 'should', 'shut', 'siz', 'someth', 'sport', 'start', 'stud', 'stund', 'stupid', 'syllab', 'tak', 'tal', 'talk', 'technolog', 'tel', 'telephon', 'thank', 'the', 'ther', 'thes', 'thi', 'thing', 'third', 'tim', 'timet', 'to', 'ttyl', 'u', 'un', 'uniform', 'univrs', 'up', 'us', 'vac', 'vary', 'visit', 'we', 'wear', 'wel', 'what', 'whatsup', 'whatv', 'when', 'wher', 'which', 'who', 'whom', 'why', 'wil', 'work', 'ya', 'year', 'yo', 'you']

# %%
print("Creating the Data for Model.....")
training = []
output = []
print("Creating an List (Empty) for Output.....")
output_empty = [0] * len(classes)

print("Creating Traning Set, Bag of Words for Model....")
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # stem each word
    pattern_words = [stemmer.stem(word.lower()) for word in pattern_words]
    # create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# Out:
# Creating the Data for Model.....
# Creating an List (Empty) for Output.....
# Creating Traning Set, Bag of Words for Model....

# %%
print("Shuffling Randomly and Converting into Numpy Array for Faster Processing...")
random.shuffle(training)
training = np.array(training)

print("Creating Train and Test Lists...")
train_x = list(training[:,0])
train_y = list(training[:,1])

print("Building Neural Network for Out Chatbot to be Contextual...")
print("Resetting graph data....")
#tf.reset_default_graph()
tf.compat.v1.reset_default_graph()
# Out:
# Shuffling Randomly and Converting into Numpy Array for Faster Processing...
# Creating Train and Test Lists...
# Building Neural Network for Out Chatbot to be Contextual...
# Resetting graph data....

# %%
import tflearn
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import gensim

# %%
#dim=300 # each word will seq of 100 
#w2v_model=gensim.models.Word2Vec(sentences=x,size=dim,window=10,min_count=1)

# %%
#tokenizer=Tokenizer()
#tokenizer.fit_on_texts(x)

# %%
#maxlen=1000
#x=pad_sequences(x,maxlen)

# %%
net = tflearn.input_data(shape=[None, len(train_x[0])])
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, 8)
net = tflearn.fully_connected(net, len(train_y[0]), activation='softmax')
net = tflearn.regression(net)
print("Training....")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tflearn/initializations.py:164: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Training....

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Embedding,LSTM,Conv1D ,MaxPool1D
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report , accuracy_score

# %%
from keras.layers import Dense, Dropout, Embedding, LSTM

# %%
model1=Sequential()

# %%
model1.add(LSTM(units=128))
model1.add(Dense(1,activation='sigmoid'))
model1.compile(optimizer='adam',loss='binary_crossentropy',metrics=['acc'])

# %%
model1.build(input_shape)

# %%
#model1.summary()

# %%
#x_train,x_test,y_train,y_test =train_test_split(x,y)
#from keras.callbacks import EarlyStopping

# %%
model = tflearn.DNN(net, tensorboard_dir='tflearn_logs')
#model2 = tflearn.LSTM(net, tensorboard_dir='tflearn_logs')

# %%
print("Training the Model.......")
model.fit(train_x, train_y,n_epoch=200, batch_size=8, show_metric=True)
print("Saving the Model.......")
model.save('model.tflearn')
# Out:
# Training Step: 10199  | total loss: 0.03545 | time: 0.260s
# | Adam | epoch: 200 | loss: 0.03545 - acc: 0.9905 -- iter: 400/403
# Training Step: 10200  | total loss: 0.03545 | time: 0.265s
# | Adam | epoch: 200 | loss: 0.03545 - acc: 0.9915 -- iter: 403/403
# --
# Saving the Model.......

# %%
print("Pickle is also Saved..")
pickle.dump( {'words':words, 'classes':classes, 'train_x':train_x, 'train_y':train_y}, open( "training_data", "wb" ) )
# Out:
# Pickle is also Saved..

# %%
print("Loading Pickle.....")
data = pickle.load( open( "training_data", "rb" ) )
words = data['words']
classes = data['classes']
train_x = data['train_x']
train_y = data['train_y']


with open('/content/sample_data/intents.json') as json_data:
    intents = json.load(json_data)
    
print("Loading the Model......")
# load our saved model
model.load('./model.tflearn')
# Out:
# Loading Pickle.....
# Loading the Model......

# %%
def clean_up_sentence(sentence):
    # It Tokenize or Break it into the constituents parts of Sentense.
    sentence_words = nltk.word_tokenize(sentence)
    # Stemming means to find the root of the word.
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words

# Return the Array of Bag of Words: True or False and 0 or 1 for each word of bag that exists in the Sentence
def bow(sentence, words, show_details=False):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

ERROR_THRESHOLD = 0.25
print("ERROR_THRESHOLD = 0.25")

def classify(sentence):
    # Prediction or To Get the Posibility or Probability from the Model
    results = model.predict([bow(sentence, words)])[0]
    # Exclude those results which are Below Threshold
    results = [[i,r] for i,r in enumerate(results) if r>ERROR_THRESHOLD]
    # Sorting is Done because heigher Confidence Answer comes first.
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append((classes[r[0]], r[1])) #Tuppl -> Intent and Probability
    return return_list

def response(sentence, userID='123', show_details=False):
    results = classify(sentence)
    # That Means if Classification is Done then Find the Matching Tag.
    if results:
        # Long Loop to get the Result.
        while results:
            for i in intents['intents']:
                # Tag Finding
                if i['tag'] == results[0][0]:
                    # Random Response from High Order Probabilities
                    return print(random.choice(i['responses']))

            results.pop(0)
# Out:
# ERROR_THRESHOLD = 0.25

# %%
while True:
    input_data = input("User - ")
    answer = response(input_data)
    if input_data=='quit':
      answer = 'ok bye!'
      break
    #answer
# Out:
# User - hi
# Hi there, how can I help?
# User - who are you
# I am your helper
# User - give me details regarding the college admission
# To know about placement visit <a target="_blank" href=https://abc.ac.in/admissions/b-tech/placement>website</a>
# User - what about the fees
# For Fee detail visit <a target="_blank" href=https://abc.ac.in/admissions/b-tech/fee>website</a>
# User - what type of uniform is there
# Boys have to wear black pants with white shirt. Girls have to wear white shirt with black overalls and pant. The uniforms should be neatly ironed.
# User - is there canteen
# Our university has canteen with different types of food available
# User - how big is the library
# There is a huge and spacious library. Timings are from 8am to 6pm and for more visit <a target="blank" href="ADD LIBRARY DETAIL LINK">here</a>
# User - what subjects do you have
# You can ask me questions regarding college, and i will try to answer them
# User - subjects
# Hi there, how can I help?
# User - bye
# Come back soon
# User - goodbye
# Come back soon
# User - quit
# It was nice talking to you
